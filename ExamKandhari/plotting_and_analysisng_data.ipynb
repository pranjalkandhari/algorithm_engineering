    return li

def str_time_to_float(line):
    array = line.split()
    return float(array[2])

ctr = 0
# 1: Exact
# 2: Heuristic 1
# 3: Exact parallel
# 4: Heuristic 1 parallel
# 5: Approximation
# 6: Approximation parallel

[1484116.062,
 1487023.3349999997,
 1440432.9760000003,
 1474801.477,
 249.824,
 458.39799999999997]

file_k_dict = {} # file_path -> k
dict_1 = {} # file_path -> result
dict_2 = {}
dict_3 = {}
dict_4 = {}
dict_5 = {}
dict_6 = {}

dict_1_time = {} # file_path -> time
dict_2_time = {}
dict_3_time = {}
dict_4_time = {}
dict_5_time = {}
dict_6_time = {}


file_path = 'ERROR'
k = -1

for line in data.splitlines():
    # print(line)
    if (ctr%27 == 1):
        print("File name:", line)
        file_path = line
    elif (ctr%27 == 2):
        print("K: ", line)
        k = k_str_to_num(line)
        file_k_dict[file_path] = k
    elif (ctr%27 == 4):
        print("Exact result:", line)
        dict_1[file_path] = str_to_int_array(line)
    elif (ctr%27 == 5):
        print("Time: ", line)
        dict_1_time[file_path] = str_time_to_float(line)
    elif (ctr%27 == 8):
        print("Heuristic 1 Result:", line)
        dict_2[file_path] = str_to_int_array(line)
    elif (ctr%27 == 9):
        print("TIme: ", line)
        dict_2_time[file_path] = str_time_to_float(line)
    elif (ctr%27 == 12):
        print("Exact parallel result:", line)
        dict_3[file_path] = str_to_int_array(line)
    elif (ctr%27 == 13):
        print("Time: ", line)
        dict_3_time[file_path] = str_time_to_float(line)
    elif (ctr%27 == 16):
        print("Heuristic 1 parallel result:", line)
        dict_4[file_path] = str_to_int_array(line)
    elif (ctr%27 == 17):
        print("Time: ", line)
        dict_4_time[file_path] = str_time_to_float(line)
    elif (ctr%27 == 20):
        print("Approximation result:", line)
        dict_5[file_path] = str_to_int_array(line)
    elif (ctr%27 == 21):
        print("Time: ", line)
        dict_5_time[file_path] = str_time_to_float(line)
    elif (ctr%27 == 24):
        print("Approximation parallel result: ", line)
        dict_6[file_path] = str_to_int_array(line)
    elif (ctr%27 == 25):
        print("Time: ", line)
        dict_6_time[file_path] = str_time_to_float(line)
    else:
        #print("ERROR!!!!")
        pass
    ctr += 1

# print(file_k_dict)
# print("-------------------")
# print(dict_1)
# print("-------------------")
# print(dict_2)
# print("-------------------")
# print(dict_3)
# print("-------------------")
# print(dict_4)
# print("-------------------")
# print(dict_5)
# print("-------------------")
# print(dict_6)
# print("-------------------")
    
# print(dict_1_time)
# print("-------------------")
# print(dict_2_time)
# print("-------------------")
# print(dict_3_time)
# print("-------------------")
# print(dict_4_time)
# print("-------------------")
# print(dict_5_time)
# print("-------------------")
# print(dict_6_time)
# print("-------------------")
import os
file_n_e_dict = {}

# Specify the directory path
directory = 'input_data/'

# List all files in the directory
files = os.listdir(directory)

# Print the list of files
for file in files:
    #print(file)
    file_path = directory + file
    print(file_path)

    with open(file_path, 'r') as file:
        # Read one line from the file
        line = file.readline()
        str_li = line.split()
        n = int(str_li[0])
        e = int(str_li[1])
        file_n_e_dict[file_path] = (n,e)

print(file_n_e_dict)
# Out:
# File name: input_data/pace_072.txt
# K:  K: 1
# Exact result:
# Time:  Execution time: 0.987 milliseconds
# Heuristic 1 Result:
# TIme:  Execution time: 0.691 milliseconds
# Exact parallel result:
# Time:  Execution time: 0.614 milliseconds
# Heuristic 1 parallel result:
# Time:  Execution time: 0.49 milliseconds
# Approximation result:
# Time:  Execution time: 0.303 milliseconds
# Approximation parallel result:
# Time:  Execution time: 1.174 milliseconds
# File name: input_data/pace_hidden_127.txt
# K:  K: 4
# Exact result:
# Time:  Execution time: 0.52 milliseconds
# Heuristic 1 Result:
# TIme:  Execution time: 0.86 milliseconds
# Exact parallel result: 11
# Time:  Execution time: 1.242 milliseconds
# Heuristic 1 parallel result: 11
# Time:  Execution time: 1.056 milliseconds
# Approximation result:
# Time:  Execution time: 0.211 milliseconds
# Approximation parallel result:
# Time:  Execution time: 1.547 milliseconds
# File name: input_data/graph_08.txt
# K:  K: 5
# ...

# %%
ctr = 0
arr = [[], [], [], [], [], []]
n_k_tup = []
time_arr = [0,0,0,0,0,0]
for file_path in file_n_e_dict.keys():
    #print(file_path)
    if (file_path in dict_1 and 
       file_path in dict_2 and
       file_path in dict_3 and
       file_path in dict_4 and
       file_path in dict_5 and
       file_path in dict_6):
        print(file_path)
        print(file_n_e_dict[file_path])
        ctr += 1
        n = file_n_e_dict[file_path][0]
        n = file_k_dict[file_path]
        #n = len(dict_1[file_path])
        k = file_k_dict[file_path]
        n_k_tup.append( (n,k) )
        arr[0].append( (n, dict_1_time[file_path]) )
        arr[1].append( (n, dict_2_time[file_path]) )
        arr[2].append( (n, dict_3_time[file_path]) )
        arr[3].append( (n, dict_4_time[file_path]) )
        arr[4].append( (n, dict_5_time[file_path]) )
        arr[5].append( (n, dict_6_time[file_path]) )
        time_arr[0] += dict_1_time[file_path]
        time_arr[1] += dict_2_time[file_path]
        time_arr[2] += dict_3_time[file_path]
        time_arr[3] += dict_4_time[file_path]
        time_arr[4] += dict_5_time[file_path]
        time_arr[5] += dict_6_time[file_path]

        
for li in arr:
    li.sort(key = lambda x: x[0])
        
print(arr)
# Out:
# input_data/graph_01.txt
# (7, 10)
# input_data/graph_02.txt
# (20, 190)
# input_data/graph_03.txt
# (7, 10)
# input_data/graph_04.txt
# (10, 15)
# input_data/graph_05.txt
# (12, 20)
# input_data/graph_06.txt
# (15, 25)
# input_data/graph_07.txt
# (8, 12)
# input_data/graph_08.txt
# (6, 8)
# input_data/graph_09.txt
# (10, 15)
# input_data/graph_10.txt
# (8, 28)
# input_data/graph_11.txt
# (15, 60)
# input_data/pace_020.txt
# (74, 92)
# input_data/pace_028.txt
# (70, 85)
# input_data/pace_036.txt
# (1741, 3169)
# input_data/pace_042.txt
# (67, 95)
# input_data/pace_046.txt
# (73, 152)
# input_data/pace_050.txt
# (49, 84)
# input_data/pace_062.txt
# (57, 78)
# input_data/pace_070.txt
# (197, 243)
# input_data/pace_072.txt
# (101, 190)
# input_data/pace_088.txt
# (2029, 3719)
# input_data/pace_091.txt
# (234, 300)
# input_data/pace_095.txt
# (67, 83)
# input_data/pace_096.txt
# (48, 64)
# input_data/pace_099.txt
# (37, 62)
# input_data/pace_hidden_111.txt
# (36, 76)
# ...

# %%
time_arr
# Out:
# [1484116.062,
#  1487023.3349999997,
#  1440432.9760000003,
#  1474801.477,
#  249.824,
#  458.39799999999997]

# %%
import matplotlib.pyplot as plt

# Create figure and axes
plt.figure(figsize=(8, 6))

# 1: Exact
# 2: Heuristic 1
# 3: Exact parallel
# 4: Heuristic 1 parallel
# 5: Approximation
# 6: Approximation parallel

ctr = 1
for li in arr:
    x = []
    y = []
    for n,time in li:
        x.append(n)
        y.append(time)
#     x = x[:15]
#     y = y[:15]
    if (ctr < 5):
        ctr += 1
        continue
    label_text = ''
    if (ctr == 1):
        label_text = 'Exact Algorithm'
    if (ctr == 2):
        label_text = 'Time heuristic Algorithm'
    if (ctr == 3):
        label_text = 'Exact parallel Algorithm'
    if (ctr == 4):
        label_text = 'Time heuristic parallel Algorithm'
    if (ctr == 5):
        label_text = 'Approximation Algorithm'
    if (ctr == 6):
        label_text = 'Approximation parallel Algorithm'
    plt.plot(x, y, label=label_text)
    ctr += 1


# Add labels and title
plt.xlabel('n')
plt.ylabel('Time (ms)')
plt.title('n vs time approximation')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
n_k_tup.sort(key = lambda x: x[0])
n_k_tup

x = []
y = []
for n,k in li:
    x.append(n)
    y.append(k)

x = x[:15]
y = y[:15]
    
plt.plot(x, y, label='n vs k')

plt.xlabel('n')
plt.ylabel('k')
plt.title('n vs k')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
n_real = []
n_app = [] # [(real, app value)]
for file_path in file_n_e_dict.keys():
    #print(file_path)
    if (file_path in dict_1 and 
       file_path in dict_2 and
       file_path in dict_3 and
       file_path in dict_4 and
       file_path in dict_5 and
       file_path in dict_6):
        n = file_n_e_dict[file_path][0]
        real = len(dict_1[file_path])
        app = len(dict_5[file_path])
        n_real.append((n, real))
        n_app.append((n, app))
n_real.sort(key = lambda x: x[0])
n_app.sort(key = lambda x: x[0])

x = []
y = []

for n,real in n_real:
    x.append(n)
    y.append(real)

plt.plot(x, y, label='Real value')

x = []
y = []

for n,app in n_app:
    x.append(n)
    y.append(app)

plt.plot(x, y, label='Approximated value')

plt.xlabel('n')
plt.ylabel('Minimum Feeback vertex set size')
plt.title('Evaluation of approximation algorithm')

# Add legend
plt.legend()

# Display the plot
plt.show()

print(x)
print(y)
# Out:
# [6, 7, 7, 8, 8, 10, 10, 12, 15, 15, 20, 32, 36, 37, 45, 48, 49, 55, 57, 61, 62, 67, 67, 69, 70, 71, 73, 73, 74, 74, 90, 101, 125, 153, 158, 197, 212, 234, 347, 1741, 2029, 2029]
# [1, 2, 2, 3, 6, 3, 2, 3, 4, 4, 18, 7, 10, 10, 8, 4, 5, 8, 5, 0, 2, 5, 2, 4, 3, 8, 11, 4, 5, 6, 2, 0, 1, 4, 6, 3, 5, 0, 5, 0, 0, 0]
